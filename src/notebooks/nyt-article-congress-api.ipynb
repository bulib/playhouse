# %% [markdown]
# # Query NYT Articles and Politician Voting Records
#
# _Committed by Jack Ammerman (@jwacooks) 2015-12-15_

# %%
import os
import pandas as pd
import numpy as np
from urllib.request import urlopen
import json
import matplotlib as plt
# %matplotlib inline
import random
import seaborn as sns
sns.set(color_codes=True)
sns.set_context('talk',font_scale=1.2, rc={"lines.linewidth": 2.5})
sns.set_style("whitegrid")
from textblob import TextBlob,Word
import time

##
## each user needs his/her API key. These can be obtained from the New York Times at:
## http://developer.nytimes.com/apps/mykeys

# %%
# api keys for NYTIMES

def get_articles(q,begin_date,end_date,page):
    base_url = 'http://api.nytimes.com/svc/search/v2/articlesearch.json?'
    article_key='<your api key>'
    qdict = {}
    if len(q) > 0:
        qdict['q'] = q
    if len(begin_date) > 0:
        qdict['begin_date'] = begin_date
    if len(end_date) > 0:
        qdict['end_date'] = end_date
    if len(page) > 0:
        qdict['page'] = page
    qdict['api-key'] = article_key
    for k,v in qdict.items():
        s = '&' + k + '=' + v
        base_url += s
    time.sleep(1)
    response = urlopen(base_url.replace('?&',"?")).read()
    return(json.loads(response.decode('utf-8')))
        

def get_congress(q,chamber,session):
    congress_key = '<your api key>'
    if q == 'current':
        base_url = 'http://api.nytimes.com/svc/politics/v3/us/legislative/congress/'
        base_url += chamber + '/'
        base_url +=  session + '/members/current.json?api-key=' + congress_key
    time.sleep(1)
    #print(base_url)
    response = urlopen(base_url.replace('?&',"?")).read()
    return(json.loads(response.decode('utf-8')))

# %%
def parse_articles(articles):
    '''
    This function takes in a response to the NYT api and parses
    the articles into a list of dictionaries
    '''
    news = []
    for i in articles['response']['docs']:
        dic = {}
        dic['id'] = i['_id']
        if i['abstract'] is not None:
            dic['abstract'] = i['abstract']#.encode("utf8")
        dic['headline'] = i['headline']['main']#.encode("utf8")
        dic['desk'] = i['news_desk']
        dic['date'] = i['pub_date'][0:10] # cutting time of day.
        dic['section'] = i['section_name']
        if i['snippet'] is not None:
            dic['snippet'] = i['snippet']#.encode("utf8")
        dic['source'] = i['source']
        dic['type'] = i['type_of_material']
        dic['url'] = i['web_url']
        dic['word_count'] = i['word_count']
        # locations
        locations = []
        for x in range(0,len(i['keywords'])):
            if 'glocations' in i['keywords'][x]['name']:
                locations.append(i['keywords'][x]['value'])
        dic['locations'] = locations
        # subject
        subjects = []
        for x in range(0,len(i['keywords'])):
            if 'subject' in i['keywords'][x]['name']:
                subjects.append(i['keywords'][x]['value'])
        dic['subjects'] = subjects   
        news.append(dic)
    return(news)

# %%
page = 0
articles_list = []
count = 0
while True:
    page += 1
    response = get_articles('gun+control','20151204','20151207',str(page))
    articles = parse_articles(response)
    articles_list += articles
    if (response['response']['meta']['offset'])  > (response['response']['meta']['hits'])+20:
        break
len(articles_list)
# Out:
# 68

# %%
#articles_list

# %%
df = pd.DataFrame(columns = ['abstract', 'date', 'desk', 'headline', 'id', 'locations', 'section',
       'snippet', 'source', 'subjects', 'type', 'url', 'word_count'])
for article in articles_list:
    df = df.append(article,ignore_index=True)

# %%
df
# Out:
#                                              abstract        date       desk  \
# 0   Ross Douthat Op-Ed column points out that libe...  2015-12-06       OpEd
# 5   566248747988100bbf963ee7
# 6   566228587988100bbf963e9c
# 7   56614d007988104d062b29ff
# 8   5664dc47798810625e85ff64
# 9   5660f3197988104d062b292e
# 10  5661ce777988100bbf963d64
# 11  5663bcfb7988103fe7de5357
# 12  5664eed9798810625e85ff8e
# 13  56614cf27988104d062b29f9
# 14  5660caa57988104d062b28bf
# 15  566248c47988100bbf963ee9
# 16  5660fd637988104d062b2949
# 17  5660ced17988104d062b28cd
# 18  566277377988100bbf963f2b
# 19  566177df7988104d062b2a97
# 20  56633bc17988103fe7de52ac
# 21  5665e9f979881015bb5baad8
# 22  5661bedb7988104d062b2ba5
# 23  566052e2798810098783fc24
# 24  5661804d7988104d062b2aaa
# 25  5665657d798810625e8600b3
# 26  5665fc5279881015bb5bab1e
# 27  566156ff7988104d062b2a17
# 28  5665c47779881015bb5baa63
# 29  5663ef5c7988103fe7de5393
# ..                       ...
# 38  5664f405798810625e85ff97
# 39  5665be0179881015bb5baa4e
# 40  566327ac7988103fe7de5285
# 41  5664d78b798810625e85ff58
# 42  566458247988103fe7de542f
# 43  5664fe0e798810625e85ffaa
# 44  5666033c79881015bb5bab31
# 45  566612f179881015bb5bab64
# 46  56657c6c798810625e8600ed
# 47  56656491798810625e8600b0
# 48  5663f4fd7988103fe7de5396
# 49  56647bdd798810625e85feb9
# 50  56651563798810625e85fff3
# 51  56648688798810625e85fece
# 52  5664df20798810625e85ff6b
# 53  566321db7988103fe7de527b
# 54  5661a1247988104d062b2b2a
# 55  566341cb7988103fe7de52b7
# 56  56636abc7988103fe7de52fc
# 57  5665154d798810625e85fff0
# 58  5664f706798810625e85ffa1
# 59  5664e706798810625e85ff7e
# 60  5664f4f0798810625e85ff99
# 61  56659978798810625e860144
# 62  56653ecf798810625e860045
# 63  5661f1ac7988100bbf963df1
# 64  56605fcd798810098783fc55
# 65  566172827988104d062b2a7d
# 66  5661764f7988104d062b2a93
# 67  565edd4c7988104cbe3b92e4
#
#                                             locations        section  \
# 0                                 [France, Australia]        Opinion
# 1                                             [Japan]          Blogs
# 2                                        [New Jersey]  N.Y. / Region
# 3                                     [United States]           U.S.
# 4                                             [Syria]        Opinion
# 5                                                  []        Opinion
# 6                           [Colorado Springs (Colo)]        Opinion
# 7                                                  []        Opinion
# 8                            [San Bernardino (Calif)]           U.S.
# 9                [New Jersey, San Bernardino (Calif)]  N.Y. / Region
# 10                           [San Bernardino (Calif)]           U.S.
# 11                                                 []           U.S.
# 12                           [San Bernardino (Calif)]           U.S.
# 13                           [San Bernardino (Calif)]        Opinion
# 14               [California, San Bernardino (Calif)]           U.S.
# 15                                                 []           U.S.
# 16            [United States, San Bernardino (Calif)]           U.S.
# 17            [San Bernardino (Calif), United States]        Opinion
# 18                                                 []           U.S.
# 19                                                 []           U.S.
# 20                 [Colorado Springs (Colo), Arizona]           U.S.
# 21                                    [United States]        Opinion
# 22                           [San Bernardino (Calif)]           U.S.
# 23  [San Bernardino (Calif), Colorado Springs (Colo)]           U.S.
# 24                                                 []     The Upshot
# 25                                                 []  N.Y. / Region
# 26                                                 []  Times Insider
# 44  http://www.nytimes.com/2015/12/07/magazine/chi...       1133
# 45  http://www.nytimes.com/2015/12/07/nytnow/your-...        727
# 46  http://www.nytimes.com/politics/first-draft/20...        387
# 47  http://www.nytimes.com/2015/12/07/nytnow/lates...       1153
# 48  http://www.nytimes.com/aponline/2015/12/06/us/...        958
# 49  http://www.nytimes.com/2015/12/07/us/politics/...       1118
# 50  http://www.nytimes.com/reuters/2015/12/07/tech...        970
# 51  http://www.nytimes.com/reuters/2015/12/06/us/p...        970
# 52  http://www.nytimes.com/reuters/2015/12/06/tech...        970
# 53  http://www.nytimes.com/2015/12/06/opinion/sund...       1795
# 54  http://www.nytimes.com/2015/12/05/business/med...       1055
# 55  http://www.nytimes.com/aponline/2015/12/05/us/...        781
# 56  http://www.nytimes.com/2015/12/06/us/politics/...       1104
# 57  http://www.nytimes.com/reuters/2015/12/07/worl...       1964
# 58  http://www.nytimes.com/reuters/2015/12/06/us/p...       1964
# 59  http://www.nytimes.com/aponline/2015/12/06/us/...       1929
# 60  http://www.nytimes.com/reuters/2015/12/06/worl...       1964
# 61  http://www.nytimes.com/reuters/2015/12/07/us/p...       1964
# 62  http://www.nytimes.com/aponline/2015/12/07/us/...       1926
# 63  http://www.nytimes.com/2015/12/05/business/dea...       1519
# 64  http://www.nytimes.com/2015/12/04/us/terrorism...       1209
# 65  http://www.nytimes.com/2015/12/04/nyregion/new...       1175
# 66  http://news.blogs.nytimes.com/2015/12/04/morni...       1709
# 67  http://www.nytimes.com/2015/12/06/magazine/fou...       4603
#
# [68 rows x 13 columns]

# %%
congress = get_congress('current','113','house')
congress_list = congress['results']
df_congress = pd.DataFrame()
members_list = congress_list[0]['members']
for member_json in members_list:
    df_congress = df_congress.append(member_json,ignore_index = True)
int_list = list(range(0, df_congress.shape[0]))
for x in int_list:
    df_congress.set_value(x,'twitter_account','@'+df_congress.ix[x]['twitter_account'])

senate = get_congress('current','113','senate')
senate_list = senate['results']
df_senate = pd.DataFrame()
members_list = senate_list[0]['members']
for member_json in members_list:
    df_senate = df_senate.append(member_json,ignore_index = True)
int_list = list(range(0, df_senate.shape[0]))
for x in int_list:
    df_senate.set_value(x,'twitter_account','@'+df_senate.ix[x]['twitter_account'])

# %%
twitter_congress = df_congress[['first_name','last_name','twitter_account']]
twitter_senate = df_senate[['first_name','last_name','twitter_account']]

# %%
twitter_congress.head(25)
# Out:
#    first_name     last_name   twitter_account
# 0      Robert      Aderholt  @Robert_Aderholt
# 1      Justin         Amash   @RepJustinAmash
# 2        Mark        Amodei    @MarkAmodeiNV2
# 3        Alma         Adams         @RepAdams
# 4     Spencer        Bachus       @BachusAL06
# 5         Joe        Barton     @RepJoeBarton
# 6      Xavier       Becerra       @RepBecerra
# 7     Sanford    Bishop Jr.    @SanfordBishop
# 8        Earl    Blumenauer  @BlumenauerMedia
# 9        John       Boehner   @SpeakerBoehner
# 10      Kevin         Brady    @RepKevinBrady
# 11    Corrine         Brown  @RepCorrineBrown
# 12     Robert         Brady         @RepBrady
# 13    Timothy        Bishop      @TimBishopNY
# 14     Marsha     Blackburn  @MarshaBlackburn
# 15  Madeleine      Bordallo                 @
# 16    Michael       Burgess  @MichaelCBurgess
# 17        Rob        Bishop     @RepRobBishop
# 18         G.   Butterfield    @GKButterfield
# 19       John        Barrow    @RepJohnBarrow
# 20    Charles  Boustany Jr.      @RepBoustany
# 21    Michele      Bachmann  @MicheleBachmann
# 22        Gus     Bilirakis  @RepGusBilirakis
# 23      Bruce        Braley      @BruceBraley
# 24       Vern      Buchanan     @VernBuchanan

# %%
twitter_senate.head(25)
# Out:
#    first_name   last_name   twitter_account
# 0       Lamar   Alexander     @SenAlexander
# 1       Kelly      Ayotte      @KellyAyotte
# 2         Roy       Blunt         @RoyBlunt
# 3     Barbara       Boxer     @SenatorBoxer
# 4     Sherrod       Brown  @SenSherrodBrown
# 5     Richard        Burr      @SenatorBurr
# 6       Tammy     Baldwin   @SenatorBaldwin
# 7        John     Boozman      @JohnBoozman
# 8        John    Barrasso  @SenJohnBarrasso
# 9        Mark      Begich                 @
# 10    Michael      Bennet      @SenBennetCo
# 11    Richard  Blumenthal    @SenBlumenthal
# 12       Cory      Booker       @CoryBooker
# 13      Maria    Cantwell    @CantwellPress
# 14   Benjamin      Cardin    @SenatorCardin
# 15     Thomas      Carper    @SenatorCarper
# 16      Saxby   Chambliss   @SaxbyChambliss
# 17     Daniel       Coats      @SenDanCoats
# 18        Tom      Coburn        @TomCoburn
# 19       Thad     Cochran   @SenThadCochran
# 20    Michael       Crapo        @MikeCrapo
# 21      Susan     Collins   @SenatorCollins
# 22       John      Cornyn       @JohnCornyn
# 23        Bob       Casey      @SenBobCasey
# 24        Bob      Corker     @SenBobCorker

# %%
voting_record_congress = df_congress[['first_name','last_name','party','state','missed_votes', 'missed_votes_pct','total_votes', 'votes_with_party_pct']]
voting_record_senate = df_senate[['first_name','last_name','party','state','missed_votes', 'missed_votes_pct','total_votes', 'votes_with_party_pct']]

# %%
voting_record_congress.head(30)
# Out:
#    first_name     last_name party state missed_votes missed_votes_pct  \
# 0      Robert      Aderholt     R    AL          110             9.23
# 1      Justin         Amash     R    MI            0             0.00
# 2        Mark        Amodei     R    NV           95             7.97
# 3        Alma         Adams     D    NC            2             4.17
# 4     Spencer        Bachus     R    AL           31             2.60
# 5         Joe        Barton     R    TX           76             6.38
# 6      Xavier       Becerra     D    CA           40             3.36
# 7     Sanford    Bishop Jr.     D    GA           74             6.21
# 8        Earl    Blumenauer     D    OR           59             4.98
# 9        John       Boehner     R    OH         1165            97.73
# 10      Kevin         Brady     R    TX           52             4.36
# 11    Corrine         Brown     D    FL           68             5.70
# 12     Robert         Brady     D    PA           20             1.68
# 13    Timothy        Bishop     D    NY           10             0.84
# 14     Marsha     Blackburn     R    TN           27             2.27
# 15  Madeleine      Bordallo     D    GU            0             0.00
# 16    Michael       Burgess     R    TX           24             2.01
# 17        Rob        Bishop     R    UT           78             6.54
# 18         G.   Butterfield     D    NC           53             4.45
# 19       John        Barrow     D    GA            0             0.00
# 20    Charles  Boustany Jr.     R    LA            8             0.67
# 21    Michele      Bachmann     R    MN           96             8.05
# 22        Gus     Bilirakis     R    FL           22             1.85
# 23      Bruce        Braley     D    IA           34             2.85
# 24       Vern      Buchanan     R    FL           45             3.78
# 25       Paul         Broun     R    GA           36             3.02
# 26        Lou      Barletta     R    PA           27             2.27
# 27      Karen          Bass     D    CA          139            11.66
# 28        Dan      Benishek     R    MI           35             2.94
# 29      Diane         Black     R    TN           16             1.34
#
#    total_votes votes_with_party_pct
# 0         1192                93.99
# 1         1192                77.01
# 2         1192                94.17
# 3           48                97.83
# 4         1192                92.94
# 5         1192                94.27
# 6         1192                95.57
# 7         1192                85.87
# 8         1185                93.52
# 9         1192                88.89
# 10        1192                95.70
# 11        1192                95.02
# 12        1192                93.77
# 13        1192                91.46
# 14        1192                96.22
# 15           0                 0.00
# 16        1192                90.15
# 17        1192                94.34
# 18        1192                93.68
# 19        1192                67.70
# 20        1192                95.35
# 21        1192                93.89
# 22        1192                95.38
# 23        1192                90.41
# 24        1192                94.68
# 25        1192                82.44
# 26        1192                93.56
# 27        1192                93.45
# 28        1192                90.32
# 29        1192                97.02

# %%
voting_record_senate.head(30)
# Out:
#      first_name   last_name party state missed_votes missed_votes_pct  \
# 0         Lamar   Alexander     R    TN           44             6.70
# 1         Kelly      Ayotte     R    NH           10             1.52
# 2           Roy       Blunt     R    MO           39             5.94
# 3       Barbara       Boxer     D    CA           44             6.70
# 4       Sherrod       Brown     D    OH           10             1.52
# 5       Richard        Burr     R    NC           19             2.89
# 6         Tammy     Baldwin     D    WI            3             0.46
# 7          John     Boozman     R    AR           68            10.35
# 8          John    Barrasso     R    WY            6             0.91
# 9          Mark      Begich     D    AK           49             7.46
# 10      Michael      Bennet     D    CO            8             1.22
# 11      Richard  Blumenthal     D    CT            2             0.30
# 12         Cory      Booker     D    NJ           12             2.78
# 13        Maria    Cantwell     D    WA            3             0.46
# 14     Benjamin      Cardin     D    MD            3             0.46
# 15       Thomas      Carper     D    DE            2             0.30
# 16        Saxby   Chambliss     R    GA           77            11.72
# 17       Daniel       Coats     R    IN           16             2.44
# 18          Tom      Coburn     R    OK          131            19.94
# 19         Thad     Cochran     R    MS          113            17.20
# 20      Michael       Crapo     R    ID            7             1.07
# 21        Susan     Collins     R    ME            0             0.00
# 22         John      Cornyn     R    TX           22             3.35
# 23          Bob       Casey     D    PA           20             3.04
# 24          Bob      Corker     R    TN           16             2.44
# 25  Christopher       Coons     D    DE           13             1.98
# 26          Ted        Cruz     R    TX           44             6.70
# 27      Richard      Durbin     D    IL            2             0.30
# 28          Joe    Donnelly     D    IN            3             0.46
# 29      Michael        Enzi     R    WY            6             0.91
#
#    total_votes votes_with_party_pct
# 0          657                85.97
# 1          657                81.45
# 2          657                89.32
# 3          657                98.04
# 4          657                97.84
# 5          657                91.38
# 6          657                98.62
# 7          657                92.53
# 8          657                91.86
# 9          657                95.72
# 10         657                97.84
# 11         657                98.63
# 12         432                98.81
# 13         657                99.24
# 14         657                99.24
# 15         657                97.40
# 16         657                85.34
# 17         657                90.33
# 18         657                86.12
# 19         657                88.97
# 20         657                89.38
# 21         657                59.67
# 22         657                89.92
# 23         657                97.65
# 24         657                85.80
# 25         657                98.29
# 26         657                87.60
# 27         657                98.93
# 28         657                94.65
# 29         657                91.86
